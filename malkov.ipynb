# %%
# !pip install networkx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
def graph_from_nested_list(lst, parent_chain=None):
    if not lst:
        return
    if isinstance(lst,str):
        # attach name for parent
        if parent_chain:
            *_, last_element = parent_chain
            last_element["name"} = lst
    elif isinstance(lst,list):
        # create node for self
        self_element = {}
